# %%
import numpy as np
import pandas as pd

file_in = '/home/andres/Fotometria/NGC3324/MAST_2023-11-23T1052/JWST/jw02731-o001_t017_nircam_clear-f200w/jw02731-o001_t017_nircam_clear-f200w_cat.ecsv'
file_out = '/home/andres/Fotometria/NGC3324/MAST_2023-11-23T1052/JWST/jw02731-o001_t017_nircam_clear-f200w/processed_data/jw02731-o001_t017_nircam_clear-f200w_cat_PROCESSED.csv'
contents = pd.read_csv(file_in, comment = '#', sep = ' ')
contents = contents.loc[contents['roundness'] !=0]
contents_extended = contents[contents['is_extended'] == True]
print(contents_extended)
contents_extended.to_csv(file_out, index = False)
# Out:
#        label     xcentroid    ycentroid  sky_centroid.ra  sky_centroid.dec
# 5          6   2482.164518    25.936994       159.126538        -58.651904  \
# 27        28   5303.347508    33.659031       159.136844        -58.628028
# 28        29   4272.846556    39.537334       159.133223        -58.636766
# 39        40   4507.188452    49.325433       159.134227        -58.634800
# 40        41    669.464073    51.251423       159.120402        -58.667301
# ...      ...           ...          ...              ...               ...
# 19070  19071  11303.438974  8534.186990       159.296598        -58.593076
# 19071  19072  11314.182815  8534.281070       159.296637        -58.592985
# 19075  19076  13488.172722  8531.763649       159.304340        -58.574560
# 19084  19085  10993.695043  8546.395909       159.295692        -58.595723
# 19087  19088  10091.009599  8550.030494       159.292533        -58.603378
#
# ...

# %%
df = pd.read_csv("../NGC3324/MAST_2023-11-23T1052/JWST/jw02731-o001_t017_nircam_clear-f200w/processed_data/jw02731-o001_t017_nircam_clear-f200w_cat_PROCESSED.ecsv") 
df
# Out:
#       label     xcentroid    ycentroid  sky_centroid.ra  sky_centroid.dec
# 0         6   2482.164518    25.936994       159.126538        -58.651904  \
# 1        28   5303.347508    33.659031       159.136844        -58.628028
# 2        29   4272.846556    39.537334       159.133223        -58.636766
# 3        40   4507.188452    49.325433       159.134227        -58.634800
# 4        41    669.464073    51.251423       159.120402        -58.667301
# ...     ...           ...          ...              ...               ...
# 2356  19071  11303.438974  8534.186990       159.296598        -58.593076
# 2357  19072  11314.182815  8534.281070       159.296637        -58.592985
# 2358  19076  13488.172722  8531.763649       159.304340        -58.574560
# 2359  19085  10993.695043  8546.395909       159.295692        -58.595723
# 2360  19088  10091.009599  8550.030494       159.292533        -58.603378
#
#       aper_bkg_flux  aper_bkg_flux_err   aper30_flux  aper30_flux_err
# ...
